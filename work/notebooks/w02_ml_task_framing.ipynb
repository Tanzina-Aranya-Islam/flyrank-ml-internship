# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Tanzina-Aranya-Islam/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (Refresh / Content Opportunity Scoring)
#
# ML task type: Ranking/scoring, with a classification-style proxy target for the starter model.
#
# The goal is to score pages according to how strongly the available observable signals indicate that they deserve review. The final output would be a ranked list of pages for a human reviewer, rather than an automatic decision.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# Target/proxy: For the starter dataset, I will use trend_direction == "down" as a proxy target for a page showing declining performance.
#
# This is only a proxy because trend_direction describes the current observed window rather than a future outcome. A stronger future version of this project could define a future-window decline target using past observations as features and later observations as the target.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# Success metric: The main metric will be Precision@K, especially Precision@50.
#
# This matches the real decision because a reviewer has limited capacity and will usually inspect only the highest-ranked pages first. Precision@50 tells us how many of the first 50 recommended pages match the chosen proxy target. Average precision can also be used to evaluate the quality of the full ranking.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# Unit of analysis: One row represents one content page in the starter dataset. The decision is made at the page level, so each page can receive a score and a ranking position for human review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

url = "https://raw.githubusercontent.com/Tanzina-Aranya-Islam/flyrank-ml-internship/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Dataset shape:", df.shape)

df[[
    "content_id",
    "impressions_90d",
    "sessions_90d",
    "content_age_days",
    "trend_direction"
]].head(10)
# Out:
# Dataset shape: (30000, 44)
#              content_id  impressions_90d  sessions_90d  content_age_days  \
# 0  content_304f48230142             3803            17               187
# 1  content_a1fb4e703a9e            15320             9               445
# 2  content_9aa793d4d895            12581            11               141
# 3  content_331d6c4de07b            11751            78               463
# 4  content_d99b7a2d90ca            19140           145               263
# 5  content_d4084a4bc775             3970             5               147
# 6  content_9a34b442b552               20             1                90
# 7  content_a63219c6e95a             1724            28               445
# 8  content_5e6c160719bc            32574            68                90
# 9  content_c27558df2b0c             1240             3               257
#
#   trend_direction
# 0            down
# 1            down
# 2            down
# 3          stable
# 4            down
# 5            down
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# A fixed rule could identify pages using a small number of manually chosen thresholds, such as high impressions combined with a declining trend. ML can consider multiple observable signals together and learn combinations that are difficult to specify manually.
#
# However, ML is not automatically better than a fixed rule. I will compare the learned ranking against a transparent baseline using metrics such as Precision@K. ML is useful only if it improves the ranking enough to justify its additional complexity while remaining understandable for human review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [X] Every section above is filled — markdown thinking AND the code that backs it
# - [X] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [X] No client names, URLs, or private queries anywhere
# - [X] My claims use careful words: observed, measured, directional, decision-support
# - [X] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
