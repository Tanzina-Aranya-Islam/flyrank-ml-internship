# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Tanzina-Aranya-Islam/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# Lane 2 — Refresh / Content Opportunity Scoring
#
# I chose the Refresh / Content Opportunity Scoring lane because I want to investigate how observable search, content, and engagement signals can help prioritize which pages deserve human review first. The goal is not to claim that a refresh will definitely improve a page, but to build an evidence-based ranking that can help a reviewer decide where to spend limited time.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# Research question: Which pages should be reviewed first for refresh, expansion, protection, pruning, or monitoring based on observable evidence?
#
# Decision: The work will help a content or SEO reviewer decide which pages should receive attention first.
#
# Action: A reviewer can inspect the highest-ranked pages and choose an appropriate action, such as refreshing, expanding, protecting, pruning, or monitoring the page.
#
# Cost of a wrong recommendation: A false positive could cause time and effort to be spent on a page that has little opportunity, while a false negative could cause a potentially important page to be overlooked. The ranking will therefore be treated as decision support rather than an automatic decision.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# Quick look at the data
#
# The starter dataset contains 30,000 rows and 44 columns. The median number of impressions over 90 days is 731, while the median number of sessions is 7. The trend direction also shows 16,262 records marked as "down", compared with 5,962 marked as "stable" and 4,388 marked as "up". These numbers suggest that the dataset contains enough variation in search visibility, traffic, and recent movement to investigate how observable signals can help prioritize pages for human review.

# %%
import pandas as pd
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/Tanzina-Aranya-Islam/flyrank-ml-internship/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Number of rows:", len(df))
print("Number of columns:", len(df.columns))

print("\nTrend direction:")
print(df["trend_direction"].value_counts())

print("\nMedian 90-day impressions:", df["impressions_90d"].median())
print("Median 90-day sessions:", df["sessions_90d"].median())
# Out:
# Number of rows: 30000
# Number of columns: 44
#
# Trend direction:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Median 90-day impressions: 731.0
# Median 90-day sessions: 7.0

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# What I can claim
#
# This project can identify observable patterns in search, content, and engagement signals and use them to support the prioritization of pages for human review. The results can provide directional evidence about which pages may deserve attention and can be used to create a ranked review list.
#
# What I cannot claim
#
# I cannot claim that a page will definitely improve after a refresh, or that the identified signals cause better search performance. I also cannot claim that the analysis predicts Google's ranking decisions or proves any Google algorithm factor. The results should be treated as observational and decision-support evidence, with human review still required.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [X] Every section above is filled — markdown thinking AND the code that backs it
# - [X] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [X] No client names, URLs, or private queries anywhere
# - [X] My claims use careful words: observed, measured, directional, decision-support
# - [X] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
